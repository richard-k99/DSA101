# %% [markdown]
# # Chemical simulation interface
# This notebook provides an interface for a toy model of a chemical reaction in the gas phase.

# %% [markdown]
# ## Import libraries

# %%
from collider import Simulation
from ipycanvas import Canvas

# %% [markdown]
# ## Initialize and run the simulation
# Initialize the Simulation class with the desired parameters and run the simulation loop.

# %%
simulation = Simulation(Canvas, 800, 600, 100, temperature=100)
simulation.canvas
# Out:
# Canvas(height=600, width=800)

# %%
simulation.run()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 simulation.run()
#
# File c:\Users\richa\OneDrive\Master\Semester 1\DSA 101\GitHub\DSA101\collider\collider.py:240, in Simulation.run(self)
#     238 while True:
#     239     self.update()
# --> 240     self.draw()
#     241     time.sleep(0.002)
#
# File c:\Users\richa\OneDrive\Master\Semester 1\DSA 101\GitHub\DSA101\collider\collider.py:224, in Simulation.draw(self)
#     223 def draw(self):
# --> 224     with hold_canvas():
#     225         self.canvas.clear()
#     226         for sphere in self.spheres:
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     140 if typ is None:
#     141     try:
# --> 142         next(self.gen)
#     143     except StopIteration:
#     144         return False
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\site-packages\ipycanvas\canvas.py:1844, in hold_canvas(canvas)
#    1842 _CANVAS_MANAGER._caching = True
#    1843 yield
# -> 1844 _CANVAS_MANAGER.flush()
#    1846 if not orig_caching:
#    1847     _CANVAS_MANAGER._caching = False
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\site-packages\ipycanvas\canvas.py:251, in _CanvasManager.flush(self)
#     248 if not self._caching or not len(self._commands_cache):
#     249     return
# --> 251 self._send_custom(self._commands_cache, self._buffers_cache)
#     253 self._commands_cache = []
#     254 self._buffers_cache = []
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\site-packages\ipycanvas\canvas.py:258, in _CanvasManager._send_custom(self, command, buffers)
#     256 def _send_custom(self, command, buffers=[]):
#     257     metadata, command_buffer = commands_to_buffer(command)
# --> 258     self.send(metadata, buffers=[command_buffer] + buffers)
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\site-packages\ipywidgets\widgets\widget.py:667, in Widget.send(self, content, buffers)
#     657 def send(self, content, buffers=None):
#     658     """Sends a custom msg to the widget model in the front-end.
#     659
#     660     Parameters
#    (...)
#     665         Binary buffers to send with message
#     666     """
# --> 667     self._send({"method": "custom", "content": content}, buffers=buffers)
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\site-packages\ipywidgets\widgets\widget.py:825, in Widget._send(self, msg, buffers)
#     823 """Sends a message to the model in the front-end."""
#     824 if self.comm is not None and (self.comm.kernel is not None if hasattr(self.comm, "kernel") else True):
# --> 825     self.comm.send(data=msg, buffers=buffers)
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\site-packages\comm\base_comm.py:147, in BaseComm.send(self, data, metadata, buffers)
#     143 def send(
#     144     self, data: MaybeDict = None, metadata: MaybeDict = None, buffers: BuffersType = None
#     145 ) -> None:
#     146     """Send a message to the frontend-side version of this comm"""
# --> 147     self.publish_msg(
#     148         "comm_msg",
#     149         data=data,
#     150         metadata=metadata,
#     151         buffers=buffers,
#     152     )
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\site-packages\ipykernel\comm\comm.py:37, in BaseComm.publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      34     self.kernel = Kernel.instance()
#      36 assert self.kernel.session is not None
# ---> 37 self.kernel.session.send(
#      38     self.kernel.iopub_socket,
#      39     msg_type,
#      40     content,
#      41     metadata=json_clean(metadata),
#      42     parent=self.kernel.get_parent(),
#      43     ident=self.topic,
#      44     buffers=buffers,
#      45 )
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\site-packages\jupyter_client\session.py:863, in Session.send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     860 elif stream:
#     861     # use dummy tracker, which will be done immediately
#     862     tracker = DONE
# --> 863     stream.send_multipart(to_send, copy=copy)
#     864 else:
#     865     tracker = DONE
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\site-packages\ipykernel\iostream.py:345, in BackgroundSocket.send_multipart(self, *args, **kwargs)
#     343 """Schedule send in IO thread"""
#     344 assert self.io_thread is not None
# --> 345 return self.io_thread.send_multipart(*args, **kwargs)
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\site-packages\ipykernel\iostream.py:275, in IOPubThread.send_multipart(self, *args, **kwargs)
#     270 def send_multipart(self, *args, **kwargs):
#     271     """send_multipart schedules actual zmq send in my thread.
#     272
#     273     If my thread isn't running (e.g. forked process), send immediately.
#     274     """
# --> 275     self.schedule(lambda: self._really_send(*args, **kwargs))
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\site-packages\ipykernel\iostream.py:266, in IOPubThread.schedule(self, f)
#     264     self._events.append(f)
#     265     # wake event thread (message content is ignored)
# --> 266     self._event_pipe.send(b"")
#     267 else:
#     268     f()
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\site-packages\zmq\sugar\socket.py:696, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     689         data = zmq.Frame(
#     690             data,
#     691             track=track,
#     692             copy=copy or None,
#     693             copy_threshold=self.copy_threshold,
#     694         )
#     695     data.group = group
# --> 696 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq\\backend\\cython\\socket.pyx:742, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\\backend\\cython\\socket.pyx:789, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\\backend\\cython\\socket.pyx:250, in zmq.backend.cython.socket._send_copy()
#
# File c:\Users\richa\anaconda3\envs\DAC_dummy\lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
